# %% [markdown]
# ## DSGE Models
# ## Problem 1

# %% [markdown]
# Charlie Walker

# %% [markdown]
# We would use a "guess and verify" approach to solve for the value function. The conjecture in the handout is that $K_{t+1}=Ae^{z_t}K_t^{\alpha}$. Plugging this functional form into both sides of the Euler equation, we get:
#
# $$\begin{align*}
# \frac{1}{(1-A)e^{z_t}K_t^{\alpha}} = \beta E\{\frac{\alpha e^{z_{t+1}}(Ae^{z_t}K_t^{\alpha})^{\alpha-1}}{e^{z_{t+1}}(Ae^{z_t}K_t^{\alpha})^{\alpha}-Ae^{z_{t+1}}(Ae^{z_t}K_t^{\alpha})^{\alpha}}\}
# \end{align*}$$
#
# Simplifying the right hand side of the equation, we get $A = \alpha\beta$.

# %% [markdown]
# ## Problem 2

# %% [markdown]
# The seven characterizing equations are:
#
# \begin{equation*}
# c_t=(1-\tau)[w_tl_t+(r_t-\delta)k_t]+k_t+T_t-k_{t+1} \text{ (Household Budget Constraint)}
# \end{equation*}
# \begin{equation*}
# \frac{1}{c_t} = \beta E\{\frac{1}{c_{t+1}}[(r_{t+1}-\delta)(1-\tau)+1]\} \text{ (Intertemporal Euler)}
# \end{equation*}
# \begin{equation*}
# a\frac{1}{1-l_t}=\frac{1}{c_t}w_t(1-\tau) \text{ (Consumption-Leisure Euler)}
# \end{equation*}
# \begin{equation*}
# r_t = \alpha e^{z_t}(\frac{l_t}{k_t})^{1-\alpha} \text{ (Firm's Capital FOC)}
# \end{equation*}
# \begin{equation*}
# w_t = (1-\alpha) e^{z_t} (\frac{k_t}{l_t})^{\alpha} \text{ (Firm's Labor FOC)}
# \end{equation*}
# \begin{equation*}
# \tau[w_tl_t+(r_t-\delta)k_t]=T_t \text{ (Government Budget Constraint)}
# \end{equation*}
# \begin{equation*}
# z_t = (1-\rho_z)\bar{z}+\rho_zz_{t-1}+\epsilon_t^z, \epsilon_t^z\sim iid(0, \sigma_z^2) \text{ (Exogenous Law of Motion)}
# \end{equation*}
#
# We cannot pull the same trick as before because now that there are more non-state variables, we cannot consolidate them all into a simple associated Euler equation. It is then impossible to come up with a "guess" that is easy to verify.
# ## Problem 3
# The seven characterizing equations are:
#
# \begin{equation*}
# c_t=(1-\tau)[w_tl_t+(r_t-\delta)k_t]+k_t+T_t-k_{t+1} \text{ (Household Budget Constraint)}
# \end{equation*}
# \begin{equation*}
# c_t^{-\gamma} = \beta E\{c_{t+1}^{-\gamma}[(r_{t+1}-\delta)(1-\tau)+1]\} \text{ (Intertemporal Euler)}
# \end{equation*}
# \begin{equation*}
# a\frac{1}{1-l_t}=c_t^{-\gamma}w_t(1-\tau) \text{ (Consumption-Leisure Euler)}
# \end{equation*}
# \begin{equation*}
# r_t = \alpha e^{z_t}(\frac{l_t}{k_t})^{1-\alpha} \text{ (Firm's Capital FOC)}
# \end{equation*}
# \begin{equation*}
# w_t = (1-\alpha) e^{z_t} (\frac{k_t}{l_t})^{\alpha} \text{ (Firm's Labor FOC)}
# \end{equation*}
# \begin{equation*}
# \tau[w_tl_t+(r_t-\delta)k_t]=T_t \text{ (Government Budget Constraint)}
# \end{equation*}
# \begin{equation*}
# z_t = (1-\rho_z)\bar{z}+\rho_zz_{t-1}+\epsilon_t^z, \epsilon_t^z\sim iid(0, \sigma_z^2) \text{ (Exogenous Law of Motion)}
# \end{equation*}
#
# ## Probelm 4
# The seven characterizing equations are:
#
# \begin{equation*}
# c_t=(1-\tau)[w_tl_t+(r_t-\delta)k_t]+k_t+T_t-k_{t+1} \text{ (Household Budget Constraint)}
# \end{equation*}
# \begin{equation*}
# c_t^{-\gamma} = \beta E\{c_{t+1}^{-\gamma}[(r_{t+1}-\delta)(1-\tau)+1]\} \text{ (Intertemporal Euler)}
# \end{equation*}
# \begin{equation*}
# a(1-l_t)^{-\epsilon}=c_t^{-\gamma}w_t(1-\tau) \text{ (Consumption-Leisure Euler)}
# \end{equation*}
# \begin{equation*}
# r_t = \alpha e^{z_t} k_t^{\eta-1}(\alpha k_t^{\eta}+(1-\alpha)l_t^{\eta})^{\frac{1-\eta}{\eta}} \text{ (Firm's Capital FOC)}
# \end{equation*}
# \begin{equation*}
# w_t = (1-\alpha) e^{z_t} l_t^{\eta-1}(\alpha k_t^{\eta}+(1-\alpha)l_t^{\eta})^{\frac{1-\eta}{\eta}} \text{ (Firm's Labor FOC)}
# \end{equation*}
# \begin{equation*}
# \tau[w_tl_t+(r_t-\delta)k_t]=T_t \text{ (Government Budget Constraint)}
# \end{equation*}
# \begin{equation*}
# z_t = (1-\rho_z)\bar{z}+\rho_zz_{t-1}+\epsilon_t^z, \epsilon_t^z\sim iid(0, \sigma_z^2) \text{ (Exogenous Law of Motion)}
# \end{equation*}
#
# ## Problem 5
# The characterizing equations are:
#
# \begin{equation*}
# c_t=(1-\tau)[w_t+(r_t-\delta)k_t]+k_t+T_t-k_{t+1} \text{ (Household Budget Constraint)}
# \end{equation*}
# \begin{equation*}
# c_t^{-\gamma} = \beta E\{c_{t+1}^{-\gamma}[(r_{t+1}-\delta)(1-\tau)+1]\} \text{ (Intertemporal Euler)}
# \end{equation*}
# \begin{equation*}
# r_t = \alpha (k_t)^{\alpha-1}(e^{z_t})^{1-\alpha} \text{ (Firm's Capital FOC)}
# \end{equation*}
# \begin{equation*}
# w_t = (1-\alpha) k_t^{\alpha}(e^{z_t})^{1-\alpha}  \text{ (Firm's Labor FOC)}
# \end{equation*}
# \begin{equation*}
# \tau[w_t+(r_t-\delta)k_t]=T_t \text{ (Government Budget Constraint)}
# \end{equation*}
# \begin{equation*}
# z_t = (1-\rho_z)\bar{z}+\rho_zz_{t-1}+\epsilon_t^z, \epsilon_t^z\sim iid(0, \sigma_z^2) \text{ (Exogenous Law of Motion)}
# \end{equation*}
#
# The steady state versions are (assuming $\bar{z} = 0$):
#
# \begin{equation*}
# \bar{c}=(1-\tau)[\bar{w}+(\bar{r}-\delta)\bar{k}]+\bar{T} \text{ (Household Budget Constraint)}
# \end{equation*}
# \begin{equation*}
# \bar{c}^{-\gamma} = \beta E\{\bar{c}^{-\gamma}[(\bar{r}-\delta)(1-\tau)+1]\} \text{ (Intertemporal Euler)}
# \end{equation*}
# \begin{equation*}
# \bar{r} = \alpha \bar{k}^{\alpha-1} \text{ (Firm's Capital FOC)}
# \end{equation*}
# \begin{equation*}
# \bar{w} = (1-\alpha) \bar{k}^{\alpha}  \text{ (Firm's Labor FOC)}
# \end{equation*}
# \begin{equation*}
# \tau[\bar{w}+(\bar{r}-\delta)\bar{k}]=\bar{T} \text{ (Government Budget Constraint)}
# \end{equation*}
#
# Now we proceed to solve for problem 5 algebraically. As with the numerical solution, I combine problem 5 with problem 6 (see below).

# %%
# Import Packages
import numpy as np
import scipy.optimize as opt
import numba
import pylab
from scipy import stats

# %%
# Define Parameters
gamma = 2.5
epsilon = 1.5
beta = 0.98
alpha = 0.4
a = 0.5
delta = 0.10
tau = 0.05
Zbar = 0

# %% [markdown]
# ## Problem 5 Algebraic Solution
# From the intertemporal euler equation we know:
# $$1 = \beta((\bar{r}-\delta)(1-\tau)+1)$$
# So we can solve for $\bar{r}$:

# %%
r_alg = (1/beta-1)/(1-tau)+delta
print(r_alg)
# Out:
# 0.1214822771213749

# %% [markdown]
# Now that we know the steady state interest rate, we can plug it into the firm's FOC for capital
# $$\bar{r} = \alpha\bar{k}^{\alpha-1}$$to solve for the value of k

# %%
k_alg = (r_alg/alpha) ** (1/(alpha-1))
print(k_alg)
# Out:
# 7.287497950692988

# %% [markdown]
# ## Problem 6
# The characterizing equations are:
#
# \begin{equation*}
# c_t=(1-\tau)[w_tl_t+(r_t-\delta)k_t]+k_t+T_t-k_{t+1} \text{ (Household Budget Constraint)}
# \end{equation*}
# \begin{equation*}
# c_t^{-\gamma} = \beta E\{c_{t+1}^{-\gamma}[(r_{t+1}-\delta)(1-\tau)+1]\} \text{ (Intertemporal Euler)}
# \end{equation*}
# \begin{equation*}
# a(1-l_t)^{-\epsilon}=c_t^{-\gamma}w_t(1-\tau) \text{ (Consumption-Leisure Euler)}
# \end{equation*}
# \begin{equation*}
# r_t = \alpha (e^{z_t})^{1-\alpha}(\frac{l_t}{k_t})^{1-\alpha} \text{ (Firm's Capital FOC)}
# \end{equation*}
# \begin{equation*}
# w_t = (1-\alpha)(e^{z_t})^{1-\alpha}(\frac{k_t}{l_t})^{\alpha}  \text{ (Firm's Labor FOC)}
# \end{equation*}
# \begin{equation*}
# \tau[w_tl_t+(r_t-\delta)k_t]=T_t \text{ (Government Budget Constraint)}
# \end{equation*}
#
# The steady state versions are (assuming $\bar{z}=0$):
#
# \begin{equation*}
# \bar{c}=(1-\tau)[\bar{w}\bar{l}+(\bar{r}-\delta)\bar{k}]+\bar{T} \text{ (Household Budget Constraint)}
# \end{equation*}
# \begin{equation*}
# \bar{c}^{-\gamma} = \beta E\{\bar{c}^{-\gamma}[(\bar{r}-\delta)(1-\tau)+1]\} \text{ (Intertemporal Euler)}
# \end{equation*}
# \begin{equation*}
# a(1-\bar{l})^{-\epsilon}=\bar{c}^{-\gamma}\bar{w}(1-\tau) \text{ (Consumption-Leisure Euler)}
# \end{equation*}
# \begin{equation*}
# \bar{r} = \alpha (\frac{\bar{l}}{\bar{k}})^{1-\alpha} \text{ (Firm's Capital FOC)}
# \end{equation*}
# \begin{equation*}
# \bar{w} = (1-\alpha)(\frac{\bar{k}}{\bar{l}})^{\alpha}  \text{ (Firm's Labor FOC)}
# \end{equation*}
# \begin{equation*}
# \tau[\bar{w}\bar{l}+(\bar{r}-\delta)\bar{k}]=\bar{T} \text{ (Government Budget Constraint)}
# \end{equation*}

# %% [markdown]
# ## Problem 5 and Problem 6 Numerical Solution
# Now we would like to find the steady state values for the model specifications in problem 5 and 6 numerically.

# %%
def get_cbar(w, r, k, l):
    c_bar = w * l + (r - delta) * k
    return c_bar

def get_rbar(k, l):
    r_bar = alpha * (l/k) ** (1 - alpha) * (np.exp(Zbar)) ** (1 - alpha)
    return r_bar

def get_wbar(k, l):
    w_bar = (1 - alpha) * (k/l) ** alpha * (np.exp(Zbar)) ** (1 - alpha)
    return w_bar
    
def euler_eqns(soln, *args):
    gamma, epsilon, beta, alpha, a, delta, tau, Zbar, problem_5 = args
    if problem_5 is False:
        w = get_wbar(soln[0], soln[1])
        r = get_rbar(soln[0], soln[1])
        c = get_cbar(w, r, soln[0], soln[1])
        eq1 = c ** (-gamma) - beta * (c ** (-gamma)* ((1 - tau) * (r - delta) + 1))
        eq2 = a * (1 - soln[1]) ** (-epsilon) - c ** (-gamma) * w * (1 - tau)  
        errors = np.array([eq1, eq2])
    else:
        w = get_wbar(soln, 1)
        r = get_rbar(soln, 1)
        c = get_cbar(w, r, soln, 1)
        errors = c ** (-gamma) - beta * (c ** (-gamma)* ((1 - tau) * (r - delta) + 1))
    return errors

def get_Tbar(w, r, k, l):
    T_bar = tau * (w * l + (r - delta) * k)
    return T_bar

def get_ibar(k):
    i_bar = delta * k
    return i_bar

def get_ybar(k, l):
    y_bar = k ** alpha * l ** (1 - alpha)
    return y_bar

# %%
args1 = (gamma, epsilon, beta, alpha, a, delta, tau, Zbar, True)
args2 = (gamma, epsilon, beta, alpha, a, delta, tau, Zbar, False)
result1 = opt.fsolve(euler_eqns, 1, args = (args1))
w1 = get_wbar(result1[0], 1)
r1 = get_rbar(result1[0], 1)
T1 = get_Tbar(w1, r1, result1[0], 1)
i1 = get_ibar(result1[0])
y1 = get_ybar(result1[0], 1)
result2 = opt.fsolve(euler_eqns, np.array([1, 0.8]), args = (args2))
k2, l2 = result2
w2 = get_wbar(result2[0], result2[1])
r2 = get_rbar(result2[0], result2[1])
c2 = get_cbar(w2, r2, k2, l2)
T2 = get_Tbar(w2, r2, result2[0], result2[1])
i2 = get_ibar(result2[0])
y2 = get_ybar(result2[0], result2[1])

print("steady-state capital for problem 5 is: "+str(result1[0]))
print("steady-state wage for problem 5 is: "+str(w1))
print("steady-state interest rate for problem 5 is: "+str(r1))
print("steady-state consumption for problem 5 is: "+str(get_cbar(w1, r1, result1[0], 1)))
print("steady-state government transfer for problem 5 is: "+str(T1))
print("steady-state investment for problem 5 is: "+str(i1))
print("steady-state output for problem 5 is: "+str(y1))
print("")
print("steady-state capital and labor for problem 6 are: "+str(result2))
print("steady-state wage for problem 6 is: "+str(w2))
print("steady-state interest rate for problem 6 is: "+str(r2))
print("steady-state consumption for problem 6 is: "+str(c2))
print("steady-state government transfer for problem 6 is: "+str(T2))
print("steady-state investment for problem 6 is: "+str(i2))
print("steady-state output for problem 6 is: "+str(y2))
# Out:
# steady-state capital for problem 5 is: 7.28749795069
# steady-state wage for problem 5 is: 1.32795276835
# steady-state interest rate for problem 5 is: 0.121482277121
# steady-state consumption for problem 5 is: 1.48450481885
# steady-state government transfer for problem 5 is: 0.0742252409425
# steady-state investment for problem 5 is: 0.728749795069
# steady-state output for problem 5 is: 2.21325461392
#
# steady-state capital and labor for problem 6 are: [ 4.22522903  0.57979145]
# steady-state wage for problem 6 is: 1.32795276835
# steady-state interest rate for problem 6 is: 0.121482277121
# steady-state consumption for problem 6 is: 0.860703206154
# steady-state government transfer for problem 6 is: 0.0430351603077
# steady-state investment for problem 6 is: 0.422522902678
# steady-state output for problem 6 is: 1.28322610883

# %% [markdown]
# So the numerical and algebraic solutions for problem 5 are the same.

# %% [markdown]
# ## Problem 8

# %%
# Import Additional Packages
import matplotlib.pyplot as plt
import ar1_approx as ar1
import time

# %%
# Specify Parameters
alpha = 0.35
beta = 0.98
rho = 0.95
sigma = 0.02
k_bar = (alpha * beta) ** (1/(1 - alpha))
print(k_bar)
# Out:
# 0.1927826194504225

# %%
# Discretize State Space
# K grid
k_lb = 0.5 * k_bar
k_ub = 1.5 * k_bar
kgrid = np.linspace(k_lb, k_ub, 25)
sizek = len(kgrid)

# z grid
step = 10 * sigma/25
pi, zgrid = ar1.rouwen(rho, 0, step, 25)
sizez = len(zgrid)

# %%
# Define utility function
u = np.zeros((sizek, sizek, sizez))
for i in range(sizek):
    for j in range(sizek):
         for k in range(sizez):
            u[i, j, k] = np.log(np.exp(zgrid[k]) * kgrid[i] ** alpha - kgrid[j])

# %%
# Value Function Iteration
VFtol = 1e-6
VFdist = 7.0
VFmaxiter = 3000
V = np.zeros((sizek, sizez))  # initial guess of value function
Vmat = np.zeros((sizek, sizek, sizez))  # initialize Vmat matrix
VFiter = 1

start = time.time()
while VFdist > VFtol and VFiter < VFmaxiter:
    TV = V
    for i in range(sizek):  # loop over k
        for j in range(sizek):  # loop over k'
            for k in range(sizez): # loop over z
                Vmat[i, j, k] = u[i, j, k] + beta * np.dot(V[j, :], pi[:, k])
    
    # iteration for graphing later
    V = Vmat.max(axis=1)  # apply max operator to Vmat (to get V(k))
    PF = np.argmax(Vmat, axis=1)  # find the index of the optimal k'
    VFdist = (np.absolute(V - TV)).max()  # check distance between value
    # function for this iteration and value function from past iteration
    VFiter += 1
end = time.time()

if VFiter < VFmaxiter:
    print('Value function converged after this many iterations:', VFiter)
    print('Time taken for convergence:' + str(end - start))
else:
    print('Value function did not converge')
# Out:
# Value function converged after this many iterations: 686
# Time taken for convergence:32.041759967803955

# %%
# Policy Function Plot
# %matplotlib inline
optK = kgrid[PF]
for i in range(1, 25, 5):
    plt.plot(kgrid, optK[:, i], label=str('z = ' + "%.2f" %zgrid[i]))
plt.plot(kgrid, kgrid, 'k:', label='45 degree line')
plt.xlabel('Capital')
plt.ylabel('Optimal Choice of Capital Next Period')
plt.legend()
plt.title('Policy Function for Brock and Mirman')
plt.show()

for i in range(25):
    plt.plot(kgrid, optK[:, i])
plt.plot(kgrid, kgrid, 'k:', label='45 degree line')
plt.xlabel('Capital')
plt.ylabel('Optimal Choice of Capital Next Period')
plt.legend()
plt.title('Policy Function for Brock and Mirman')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# %matplotlib notebook
fig = plt.figure(figsize=(10, 8))
zmat, kmat = np.meshgrid(kgrid, zgrid)
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(kmat, zmat, optK, rstride=1, cstride=1, cmap=cm.Blues,
                linewidth=0, antialiased=False)
ax.view_init(elev=20., azim=20)  # to rotate plot for better view
ax.set_xlabel(r'Productivity')
ax.set_ylabel(r'Capital')
ax.set_zlabel(r'Policy Function')
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# ## Linearization
# ## Problem 1

# %% [markdown]
# To linearize, we would like to write a gamma function in terms of the state variables, based on the Euler Equation, first. The Euler equation for the Brock-Mirman Model is:
# $\frac{1}{e^{z_t}K_t^\alpha - K_{t+1}} = \beta E_t\{\frac{\alpha e^{z_{t+1}}K_{t+1}^{\alpha-1}}{e^{z_{t+1}}K_{t+1}^{\alpha}-K_{t+2}}\}$， so by rewritting the associated Euler equation, we get:
# $\Gamma(K_{t+2}, K_{t+1}, K_{t}, z_{t+1}, z_{t}) = \frac{1}{e^{z_t}K_t^\alpha - K_{t+1}} = \beta E_t\{\frac{\alpha e^{z_{t+1}}K_{t+1}^{\alpha-1}}{e^{z_{t+1}}K_{t+1}^{\alpha}-K_{t+2}}\}$

# %%
def Modeldyn(theta0, params):
    '''
    This function takes vectors of endogenous and exogenous state variables
    along with a vector of 'jump' variables and returns values from the
    characterizing Euler equations.
    
    Inputs are:
        theta: a vector containng (Kpp, Kp, K, Zp, Z) where:
            Kpp: value of capital in two periods
            Kp: value of capital in next period
            K: value of capital this period
            Zp: value of productivity in next period
            Z: value of productivity this period
        params: list of parameter values
    
    Output are:
        Euler: an associated Euler equation rewritten so that they are zero at the
            steady state values of X, Y & Z.  
    '''
    
    # unpack theat0
    (Kpp, Kp, K, Zp, Z) = theta0
    
    E = 1/(np.exp(Z) * K ** alpha - Kp) - beta * ((alpha * np.exp(Zp) * Kp ** (alpha - 1))/ 
                                             (np.exp(Zp) * Kp ** alpha - Kpp))
                                                                            
    return E

# %%
from LinApp_FindSS import LinApp_FindSS
from LinApp_Deriv import LinApp_Deriv
from LinApp_Solve import LinApp_Solve

# %% [markdown]
# First we would like to find the steady-state values:

# %%
# set parameter values
alpha = .35
beta = .98
rho = 0.95
sigma = 0.02

# make parameter list to pass to functions
params = (alpha, beta, rho, sigma)

# set LinApp parameters
Zbar = np.array([0.])
nk = 1
nz = 1

# %%
# take a guess for steady state values of k and ell
guessk = np.array([.15])

# find the steady state values using LinApp_FindSS
kbar = LinApp_FindSS(Modeldyn, params, guessk, Zbar, nk, 0)[0]
print ('Kbar: ', kbar)

# set up steady state input vector
theta0 = np.array([kbar, kbar, kbar, 0., 0.])

# check SS solution
check = Modeldyn(theta0, params)
print ('check: ', check)
if np.max(np.abs(check)) > 1.E-6:
    print ('Have NOT found steady state')
# Out:
# Kbar:  0.19278261945
# check:  -2.6645352591e-15

# %% [markdown]
# Next, we need to find the parameter matrics: $F, G, H, L, M, N$, using the function LinApp_Deriv.

# %%
[AA, BB, CC, DD, FF, GG, HH, JJ, KK, LL, MM, WW, TT] = \
    LinApp_Deriv(Modeldyn, params, theta0, nk, 0, nz, logX=False)
NN = np.array([rho])
print('FF: ', FF[0])
print('GG: ', GG[0])
print('HH: ', HH[0])
print('LL: ', LL[0])
print('MM: ', MM[0])
print('NN: ', NN)
# Out:
# FF:  [-7.33367648]
# GG:  [ 23.9477678]
# HH:  [-7.48334336]
# LL:  [ 1.41380536]
# MM:  [-4.12188152]
# NN:  [ 0.95]

# %% [markdown]
# Finally, we want to calculate the policy function, using LinApp_Solve, given the parameters.

# %%
PP, QQ, UU, RR, SS, VV = \
    LinApp_Solve(AA,BB,CC,DD,FF,GG,HH,JJ,KK,LL,MM,WW,TT,NN,Zbar,Sylv=0)
print ('PP:',PP[0])
print ('QQ', QQ[0])
# Calculate Policy Function
optK1 = np.zeros((sizek, sizez))
for i in range(sizek):
    optK1[i,:] =  (PP[0] * (kgrid[i] - kbar) + QQ[0] * (zgrid - 0)) + kbar
# Out:
# PP: [ 0.35]
# QQ [ 0.19278262]

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(10, 8))
zmat, kmat = np.meshgrid(kgrid, zgrid)
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(kmat, zmat, optK1, rstride=1, cstride=1, cmap=cm.Blues,
                linewidth=0, antialiased=False)
ax.view_init(elev=20., azim=20)  # to rotate plot for better view
ax.set_xlabel(r'Productivity')
ax.set_ylabel(r'Capital')
ax.set_zlabel(r'Policy Function')
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# The plot obtained from grid search could be found above. The general  shapes of the policy functions are pretty similar. Now we would like to compare this plot with the one obtained from closed form solution.

# %%
optK2 = np.zeros((sizek, sizez))
for i in range(sizek):
    for j in range(sizez):
        optK2[i, j] = alpha * beta * kgrid[i] ** alpha * np.exp(zgrid[j])

# %matplotlib notebook
fig = plt.figure(figsize=(10, 8))
zmat, kmat = np.meshgrid(kgrid, zgrid)
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(kmat, zmat, optK2, rstride=1, cstride=1, cmap=cm.Blues,
                linewidth=0, antialiased=False)
ax.view_init(elev=20., azim=20)  # to rotate plot for better view
ax.set_xlabel(r'Productivity')
ax.set_ylabel(r'Capital')
ax.set_zlabel(r'Policy Function')
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# Now we would plot the three curves on the same graph.

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(10, 8))
zmat, kmat = np.meshgrid(kgrid, zgrid)
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(kmat, zmat, optK, rstride=1, cstride=1, cmap=cm.Greens,
                linewidth=0, antialiased=False)
ax.plot_surface(kmat, zmat, optK1, rstride=1, cstride=1, cmap=cm.Reds,
                linewidth=0, antialiased=False)
ax.plot_surface(kmat, zmat, optK2, rstride=1, cstride=1, cmap=cm.Blues,
                linewidth=0, antialiased=False)
ax.view_init(elev=20., azim=20)  # to rotate plot for better view
ax.set_xlabel(r'Productivity')
ax.set_ylabel(r'Capital')
ax.set_zlabel(r'Policy Function')
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# We see that the three plots are all very similar.

# %% [markdown]
# ## Problem 2

# %%
[AA, BB, CC, DD, FF, GG, HH, JJ, KK, LL, MM, WW, TT] = \
    LinApp_Deriv(Modeldyn, params, theta0, nk, 0, nz, logX=True)
NN = np.array([rho])
print('FF: ', FF[0])
print('GG: ', GG[0])
print('HH: ', HH[0])
print('LL: ', LL[0])
print('MM: ', MM[0])
print('NN: ', NN)
# Out:
# FF:  [-1.41380536]
# GG:  [ 4.61671341]
# HH:  [-1.44265853]
# LL:  [ 1.41380536]
# MM:  [-4.12188152]
# NN:  [ 0.95]

# %%
PP, QQ, UU, RR, SS, VV = \
    LinApp_Solve(AA,BB,CC,DD,FF,GG,HH,JJ,KK,LL,MM,WW,TT,NN,Zbar,Sylv=1)
print ('PP:',PP[0])
print ('QQ', QQ[0])
# Calculate Policy Function
optK3 = np.zeros((sizek, sizez))
for i in range(sizek):
    for j in range(sizez):
        optK3[i,j] =  (PP[0] * ((kgrid[i] - kbar) / kbar) + QQ[0] * zgrid[j]) * kbar + kbar
# Out:
# Using Sylvester equation solver...
# PP: [ 0.35]
# QQ [ 1.]

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(10, 8))
zmat, kmat = np.meshgrid(kgrid, zgrid)
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(kmat, zmat, optK, rstride=1, cstride=1, cmap=cm.Greens,
                linewidth=0, antialiased=False)
ax.plot_surface(kmat, zmat, optK3, rstride=1, cstride=1, cmap=cm.Reds,
                linewidth=0, antialiased=False)
ax.plot_surface(kmat, zmat, optK2, rstride=1, cstride=1, cmap=cm.Blues,
                linewidth=0, antialiased=False)
ax.view_init(elev=20., azim=20)  # to rotate plot for better view
ax.set_xlabel(r'Productivity')
ax.set_ylabel(r'Capital')
ax.set_zlabel(r'Policy Function')
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# ## Problem 3
# From equation (7), we get
#
# \begin{equation*}
# 			\tilde{X}_{t+1}=P\tilde{X}_t+Q\tilde{Z}_{t+1}=P^2\tilde{X}_{t-1}+(NQ+Q)\tilde{Z}_t
# \end{equation*}
#
# Plugging the equation above, as well as equation (6) and (7) into equation (5), we get
#
# \begin{align*}
# 		F(P^2\tilde{X}_{t-1}+(NQ+Q)\tilde{Z}_t)+G(P\tilde{X}_{t-1}+Q\tilde{Z}_t)+H\tilde{X}_{t-1}+LN\tilde{Z}_t+M\tilde{Z}_t &= 0.\\
# 		[(FP+Q)P+H]\tilde{X}_{t-1}+[(FQ+L)N+(FP+G)Q+M]\tilde{Z}_t &=0
# \end{align*}

# %% [markdown]
# ## Problem 4
# Here we solve for the steady-state values using the LinApp functions, by letting the $k_{t-1}$ be the state variables.

# %%
def get_c(w, r, kp, k, l):
    c = w * l + (r - delta) * k + k - kp
    return c

def get_r(k, l, z):
    r = alpha * (l/k) ** (1 - alpha) * (np.exp(z)) ** (1 - alpha)
    return r

def get_w(k, l, z):
    w = (1 - alpha) * (k/l) ** alpha * (np.exp(z)) ** (1 - alpha)
    return w

# %%
def Modeldyn(theta0, params):
    # unpack theat0
    (Xpp, Xp, X, Yp, Y, Zp, Z) = theta0
    w = get_w(X, Y, Z)
    wp = get_w(Xp, Yp, Zp)
    r = get_r(X, Y, Z)
    rp = get_r(Xp, Yp, Zp)
    c = get_c(w, r, Xp, X, Y)
    cp = get_c(wp, rp, Xpp, Xp, Yp)
    # Evaluate Euler equations
    E1 = a * (1 - Y) ** (-epsilon) - (c ** (-gamma) * w * (1 - tau)) 
    E2 = c ** (-gamma)  - beta * (cp ** (-gamma)* ((1 - tau) * (rp - delta) + 1))
    
    return np.array([E1, E2])

# %%
# set parameter values
gamma = 2.5
epsilon = 1.5
beta = 0.98
alpha = 0.4
a = 0.5
delta = 0.10
tau = 0.05
rho = 0.9

# make parameter list to pass to functions
params = (gamma, epsilon, beta, alpha, a, delta, tau)

# set LinApp parameters
Zbar = np.array([0.])
nx = 1
ny = 1
nz = 1

# %%
# take a guess for steady state values of k and ell
guessXY = np.array([4, .25])

# find the steady state values using LinApp_FindSS
XYbar = LinApp_FindSS(Modeldyn, params, guessXY, Zbar, nx, ny)
(kbar, lbar) = XYbar
print ('XYbar: ', XYbar)

# set up steady state input vector
theta0 = np.array([kbar, kbar, kbar, lbar, lbar, 0., 0.])

# check SS solution
check = Modeldyn(theta0, params)
print ('check: ', check)
if np.max(np.abs(check)) > 1.E-6:
    print ('Have NOT found steady state')
# Out:
# XYbar:  [ 4.22522903  0.57979145]
# check:  [ -1.33448808e-13  -1.11022302e-14]

# %% [markdown]
# So the steady-state values for capital and labor are the same as caculated in exercise 6 of the section "DSGE Models." Please refer to that problem for other steady-state values.

# %% [markdown]
# ## Problem 5
# Here we calculate for derivatives numerically, by changing each x variable by a small number (0.001) and calculating the slope.

# %%
gamma = 2.5
epsilon = 1.5
beta = 0.98
alpha = 0.4
a = 0.5
delta = 0.10
tau = 0.05
Zbar = 0
e = 1.001
e1 = e - 1

# %%
delta *= e

arg
w = get_wbar(k, l)s2 = (gamma, epsilon, beta, alpha, a, delta, tau, Zbar, False)
k, l = opt.fsolve(euler_eqns, np.array([1, 0.8]), args = (args2))
r = get_rbar(k, l)
c = get_cbar(w, r, k, l)
T = get_Tbar(w, r, k, l)
i = get_ibar(k)
y = get_ybar(k, l)
print('dk/d(delta): '+str((k-k2)/(delta/e * e1)))
print('dl/d(delta): '+str((l-l2)/(delta/e * e1)))
print('dw/d(delta): '+str((w-w2)/(delta/e * e1)))
print('dr/d(delta): '+str((r-r2)/(delta/e * e1)))
print('dc/d(delta): '+str((c-c2)/(delta/e * e1)))
print('dT/d(delta): '+str((T-T2)/(delta/e * e1)))
print('di/d(delta): '+str((i-i2)/(delta/e * e1)))
print('dy/d(delta): '+str((y-y2)/(delta/e * e1)))

delta /= e
# Out:
# dk/d(delta): -48.3042377918
# dl/d(delta): 1.31911928927
# dw/d(delta): -7.2825025926
# dr/d(delta): 0.999999999998
# dc/d(delta): -3.50925032025
# dT/d(delta): -0.175462516012
# di/d(delta): -0.610025176179
# dy/d(delta): -4.11927549642

# %%
alpha *= e

args2 = (gamma, epsilon, beta, alpha, a, delta, tau, Zbar, False)
k, l = opt.fsolve(euler_eqns, np.array([1, 0.8]), args = (args2))
w = get_wbar(k, l)
r = get_rbar(k, l)
c = get_cbar(w, r, k, l)
T = get_Tbar(w, r, k, l)
i = get_ibar(k)
y = get_ybar(k, l)
print('dk/d(alpha): '+str((k-k2)/(alpha/e * e1)))
print('dl/d(alpha): '+str((l-l2)/(alpha/e * e1)))
print('dw/d(alpha): '+str((w-w2)/(alpha/e * e1)))
print('dr/d(alpha): '+str((r-r2)/(alpha/e * e1)))
print('dc/d(alpha): '+str((c-c2)/(alpha/e * e1)))
print('dT/d(alpha): '+str((T-T2)/(alpha/e * e1)))
print('di/d(alpha): '+str((i-i2)/(alpha/e * e1)))
print('dy/d(alpha): '+str((y-y2)/(alpha/e * e1)))

alpha /= e
# Out:
# dk/d(alpha): 26.0219827095
# dl/d(alpha): -0.77016225398
# dw/d(alpha): 4.40357425301
# dr/d(alpha): 6.10622663544e-12
# dc/d(alpha): 2.0880704752
# dT/d(alpha): 0.10440352376
# di/d(alpha): 2.60219827095
# dy/d(alpha): 4.69026874615

# %%
tau *= e

args2 = (gamma, epsilon, beta, alpha, a, delta, tau, Zbar, False)
k, l = opt.fsolve(euler_eqns, np.array([1, 0.8]), args = (args2))
w = get_wbar(k, l)
r = get_rbar(k, l)
c = get_cbar(w, r, k, l)
T = get_Tbar(w, r, k, l)
i = get_ibar(k)
y = get_ybar(k, l)

print('dk/d(tau): '+str((k-k2)/(tau/e * e1)))
print('dl/d(tau): '+str((l-l2)/(tau/e * e1)))
print('dw/d(tau): '+str((w-w2)/(tau/e * e1)))
print('dr/d(tau): '+str((r-r2)/(tau/e * e1)))
print('dc/d(tau): '+str((c-c2)/(tau/e * e1)))
print('dT/d(tau): '+str((T-T2)/(tau/e * e1)))
print('di/d(tau): '+str((i-i2)/(tau/e * e1)))
print('dy/d(tau): '+str((y-y2)/(tau/e * e1)))

tau /= e
# Out:
# dk/d(tau): -2.32328890204
# dl/d(tau): -0.138927338398
# dw/d(tau): -0.164799027615
# dr/d(tau): 0.0226141135076
# dc/d(tau): -0.234399220747
# dT/d(tau): 0.848971525156
# di/d(tau): -0.232328890204
# dy/d(tau): -0.466728110946

# %%
gamma *= e

args2 = (gamma, epsilon, beta, alpha, a, delta, tau, Zbar, False)
k, l = opt.fsolve(euler_eqns, np.array([1, 0.8]), args = (args2))
w = get_wbar(k, l)
r = get_rbar(k, l)
c = get_cbar(w, r, k, l)
T = get_Tbar(w, r, k, l)
i = get_ibar(k)
y = get_ybar(k, l)
print('dk/d(gamma): '+str((k-k2)/(gamma/e * e1)))
print('dl/d(gamma): '+str((l-l2)/(gamma/e * e1)))
print('dw/d(gamma): '+str((w-w2)/(gamma/e * e1)))
print('dr/d(gamma): '+str((r-r2)/(gamma/e * e1)))
print('dc/d(gamma): '+str((c-c2)/(gamma/e * e1)))
print('dT/d(gamma): '+str((T-T2)/(gamma/e * e1)))
print('di/d(gamma): '+str((i-i2)/(gamma/e * e1)))
print('dy/d(gamma): '+str((y-y2)/(gamma/e * e1)))
gamma /= e
# Out:
# dk/d(gamma): 0.138622949123
# dl/d(gamma): 0.0190220223855
# dw/d(gamma): -3.73034936274e-12
# dr/d(gamma): 4.99600361081e-13
# dc/d(gamma): 0.0282382838948
# dT/d(gamma): 0.00141191419474
# di/d(gamma): 0.0138622949123
# dy/d(gamma): 0.0421005788071

# %%
beta *= e

args2 = (gamma, epsilon, beta, alpha, a, delta, tau, Zbar, False)
k, l = opt.fsolve(euler_eqns, np.array([1, 0.8]), args = (args2))
w = get_wbar(k, l)
r = get_rbar(k, l)
c = get_cbar(w, r, k, l)
T = get_Tbar(w, r, k, l)
i = get_ibar(k)
y = get_ybar(k, l)
print('dk/d(beta): '+str((k-k2)/(beta/e * e1)))
print('dl/d(beta): '+str((l-l2)/(beta/e * e1)))
print('dw/d(beta): '+str((w-w2)/(beta/e * e1)))
print('dr/d(beta): '+str((r-r2)/(beta/e * e1)))
print('dc/d(beta): '+str((c-c2)/(beta/e * e1)))
print('dT/d(beta): '+str((T-T2)/(beta/e * e1)))
print('di/d(beta): '+str((i-i2)/(beta/e * e1)))
print('dy/d(beta): '+str((y-y2)/(beta/e * e1)))

beta /= e
# Out:
# dk/d(beta): 66.2268287151
# dl/d(beta): 0.270418398584
# dw/d(beta): 8.03856920845
# dr/d(beta): -1.09493960739
# dc/d(beta): 1.74719527055
# dT/d(beta): 0.0873597635274
# di/d(beta): 6.62268287151
# dy/d(beta): 8.36987814206

# %%
epsilon *= e

args2 = (gamma, epsilon, beta, alpha, a, delta, tau, Zbar, False)
k, l = opt.fsolve(euler_eqns, np.array([1, 0.8]), args = (args2))
w = get_wbar(k, l)
r = get_rbar(k, l)
c = get_cbar(w, r, k, l)
T = get_Tbar(w, r, k, l)
i = get_ibar(k)
y = get_ybar(k, l)
print('dk/d(epsilon): '+str((k-k2)/(epsilon/e * e1)))
print('dl/d(epsilon): '+str((l-l2)/(epsilon/e * e1)))
print('dw/d(epsilon): '+str((w-w2)/(epsilon/e * e1)))
print('dr/d(epsilon): '+str((r-r2)/(epsilon/e * e1)))
print('dc/d(epsilon): '+str((c-c2)/(epsilon/e * e1)))
print('dT/d(epsilon): '+str((T-T2)/(epsilon/e * e1)))
print('di/d(epsilon): '+str((i-i2)/(epsilon/e * e1)))
print('dy/d(epsilon): '+str((y-y2)/(epsilon/e * e1)))

epsilon /= e
# Out:
# dk/d(epsilon): -0.801302275761
# dl/d(epsilon): -0.109955676254
# dw/d(epsilon): -6.41833253212e-08
# dr/d(epsilon): 8.80732523948e-09
# dc/d(epsilon): -0.163229742223
# dT/d(epsilon): -0.00816148711115
# di/d(epsilon): -0.0801302275761
# dy/d(epsilon): -0.243359969799

# %%
a *= e

args2 = (gamma, epsilon, beta, alpha, a, delta, tau, Zbar, False)
k, l = opt.fsolve(euler_eqns, np.array([1, 0.8]), args = (args2))
w = get_wbar(k, l)
r = get_rbar(k, l)
c = get_cbar(w, r, k, l)
T = get_Tbar(w, r, k, l)
i = get_ibar(k)
y = get_ybar(k, l)
print('dk/d(a): '+str((k-k2)/(a/e * e1)))
print('dl/d(a): '+str((l-l2)/(a/e * e1)))
print('dw/d(a): '+str((w-w2)/(a/e * e1)))
print('dr/d(a): '+str((r-r2)/(a/e * e1)))
print('dc/d(a): '+str((c-c2)/(a/e * e1)))
print('dT/d(a): '+str((T-T2)/(a/e * e1)))
print('di/d(a): '+str((i-i2)/(a/e * e1)))
print('dy/d(a): '+str((y-y2)/(a/e * e1)))

a /= e
# Out:
# dk/d(a): -1.84834638931
# dl/d(a): -0.253632508949
# dw/d(a): -1.37667655054e-11
# dr/d(a): 1.85962356625e-12
# dc/d(a): -0.376518681754
# dT/d(a): -0.0188259340877
# di/d(a): -0.184834638931
# dy/d(a): -0.561353320685

# %%
Zbar += 0.001

args2 = (gamma, epsilon, beta, alpha, a, delta, tau, Zbar, False)
k, l = opt.fsolve(euler_eqns, np.array([1, 0.8]), args = (args2))
w = get_wbar(k, l)
r = get_rbar(k, l)
c = get_cbar(w, r, k, l)
T = get_Tbar(w, r, k, l)
i = get_ibar(k)
y = get_ybar(k, l)
print('dk/d(zbar): '+str((k-k2)/0.001))
print('dl/d(zbar): '+str((l-l2)/0.001))
print('dw/d(zbar): '+str((w-w2)/0.001))
print('dr/d(zbar): '+str((r-r2)/0.001))
print('dc/d(zbar): '+str((c-c2)/0.001))
print('dT/d(zbar): '+str((T-T2)/0.001))
print('di/d(zbar): '+str((i-i2)/0.001))
print('dy/d(zbar): '+str((y-y2)/0.001))

Zbar -= 0.001
# Out:
# dk/d(zbar): 2.83899601428
# dl/d(zbar): -0.190320283904
# dw/d(zbar): 1.32861696611
# dr/d(zbar): 1.4294121442e-12
# dc/d(zbar): 0.57831964997
# dT/d(zbar): 0.0289159824985
# di/d(zbar): 0.283899601428
# dy/d(zbar): 0.0919973442262

# %% [markdown]
# ## Problem 6

# %%
def get_c(w, r, kp, k, l):
    c = w * l + (r - delta) * k + k - kp
    return c

def get_r(k, l, z):
    r = alpha * (l/k) ** (1 - alpha) * (np.exp(z)) ** (1 - alpha)
    return r

def get_w(k, l, z):
    w = (1 - alpha) * (k/l) ** alpha * (np.exp(z)) ** (1 - alpha)
    return w

# %%
def Modeldyn(theta0, params):
    # unpack theta0
    (Xpp, Ypp, Xp, Yp, X, Y, Zp, Z) = theta0
    w = get_w(X, Yp, Z)
    wp = get_w(Xp, Ypp, Zp)
    r = get_r(X, Yp, Z)
    rp = get_r(Xp, Ypp, Zp)
    c = get_c(w, r, Xp, X, Yp)
    cp = get_c(wp, rp, Xpp, Xp, Ypp)
    # Evaluate Euler equations
    E1 = a * (1 - Yp) ** (-epsilon)  - (c ** (-gamma) * w * (1 - tau))
    E2 = c ** (-gamma) - ( beta * (cp ** (-gamma)* ((1 - tau) * (rp - delta) + 1))) 
    
    return np.array([E1, E2])

# %%
# set parameter values
gamma = 2.5
epsilon = 1.5
beta = 0.98
alpha = 0.4
a = 0.5
delta = 0.10
tau = 0.05
rho = 0.9

# make parameter list to pass to functions
params = (gamma, epsilon, beta, alpha, a, delta, tau)

# set LinApp parameters
Zbar = np.array([0.])
nx = 2
ny = 0
nz = 1

# %%
# take a guess for steady state values of k and ell
guessXY = np.array([4, .25])

# find the steady state values using LinApp_FindSS
XYbar = LinApp_FindSS(Modeldyn, params, guessXY, Zbar, nx, ny)
(kbar, lbar) = XYbar
print ('XYbar: ', XYbar)

# set up steady state input vector
theta0 = np.array([kbar, lbar, kbar, lbar, kbar, lbar, 0., 0.])

# check SS solution
check = Modeldyn(theta0, params)
k_ss, l_ss = XYbar
print ('check: ', check)
if np.max(np.abs(check)) > 1.E-6:
    print ('Have NOT found steady state')
# Out:
# XYbar:  [ 4.22522903  0.57979145]
# check:  [ -1.33448808e-13  -1.11022302e-14]

# %%
# find the derivatives matrices
[AA, BB, CC, DD, FF, GG, HH, JJ, KK, LL, MM, WW, TT] = \
    LinApp_Deriv(Modeldyn, params, theta0, nx, ny, nz, logX=True)
print('FF: ', FF)
print('GG: ', GG)
print('HH: ', HH)
print('LL: ', LL)
print('MM: ', MM)

# set value for NN    
NN = rho
    
# find the policy and jump function coefficients
PP, QQ, UU, RR, SS, VV = \
    LinApp_Solve(AA,BB,CC,DD,FF,GG,HH,JJ,KK,LL,MM,WW,TT,NN,Zbar,Sylv=1)
print ('PP:',PP)
print ('QQ', QQ)
# Out:
# FF:  [[  0.           0.        ]
#  [-17.85678587   3.15518743]]
# GG:  [[-22.52731982   8.63824988]
#  [ 36.19591326  -3.25392452]]
# HH:  [[ 22.27702702   0.        ]
#  [-18.2403903    0.        ]]
# LL:  [[ 0.        ]
#  [ 3.15518743]]
# MM:  [[ 3.00365877]
#  [-3.25392451]]
# Sylvester equation solver condition is not satisfied; proceed with the original method...
# PP: [[ 0.9152937   0.        ]
#  [-0.19192697  0.        ]]
# QQ [[ 0.1289971 ]
#  [-0.01131015]]

# %% [markdown]
# ## Problem 7

# %%
# Simulation
sigmaz = 0.02
e = np.random.normal(0, scale=sigmaz, size=(10000, 251))

z = np.zeros_like(e)
z[:, 0] = np.zeros(10000)
for i in range(1, 251):
    z[:, i] = rho * z[:, i - 1] + e[:, i]

k = np.zeros_like(e)
l = np.zeros_like(e)
c = np.zeros_like(e)
y = np.zeros_like(e)
I = np.zeros_like(e)


for i in range(1, 251):
    k[:, i] = PP[0, 0] * k[:, i - 1] + QQ[0, 0] * z[:, i] 
    l[:, i] = PP[1, 0] * k[:, i - 1] + QQ[1, 0] * z[:, i]
k = k_ss * np.exp(k)
l = l_ss * np.exp(l)

w = get_w(k, l, z)
r = get_r(k, l, z)

for i in range(250):
    y[:, i] = k[:, i] ** alpha * l[:, i] ** (1 - alpha) * np.exp(z[:, i])
    I[:, i] = k[:, i + 1] - (1 - delta) * k[:, i]
    c[:, i] = w[:, i] * l[:, i] + (r[:, i] - delta) * k[:, i] + k[:, i] - k[:, i+1]
y = y[:, 0:250]
I = I[:, 0:250]
c = c[:, 0:250]
l = l[:, 0:250]
ymean = y.mean(axis=0)
cmean = c.mean(axis=0)
Imean = I.mean(axis=0)
lmean = l.mean(axis=0)

# %%
ymin = np.zeros(250)
ymax = np.zeros(250)
cmin = np.zeros(250)
cmax = np.zeros(250)
Imin = np.zeros(250)
Imax = np.zeros(250)
lmin = np.zeros(250)
lmax = np.zeros(250)
for i in range(250):
    ymin[i] = np.percentile(y[:, i], 5)
    ymax[i] = np.percentile(y[:, i], 95)
    cmin[i] = np.percentile(c[:, i], 5)
    cmax[i] = np.percentile(c[:, i], 95)
    Imin[i] = np.percentile(I[:, i], 5)
    Imax[i] = np.percentile(I[:, i], 95)
    lmin[i] = np.percentile(l[:, i], 5)
    lmax[i] = np.percentile(l[:, i], 95)
import matplotlib.pyplot as plt
pylab.rcParams['figure.figsize'] = (10, 5)
plt.subplot(221)
plt.plot(np.arange(0, 250), ymean[0: 250], c='r')
plt.plot(np.arange(0, 250), ymin, c ='g')
plt.plot(np.arange(0, 250), ymax, c ='b')
plt.title("Output Plot")
plt.subplot(222)
plt.plot(np.arange(0, 250), cmean[0: 250], c='r')
plt.plot(np.arange(0, 250), cmin, c ='g')
plt.plot(np.arange(0, 250), cmax, c ='b')
plt.title("Consumption Plot")
plt.subplot(223)
plt.plot(np.arange(0, 250), Imean[0: 250], c='r')
plt.plot(np.arange(0, 250), Imin, c ='g')
plt.plot(np.arange(0, 250), Imax, c ='b')
plt.title("Investmenr Plot")
plt.subplot(224)
plt.plot(np.arange(0, 250), lmean[0: 250], c='r')
plt.plot(np.arange(0, 250), lmin, c ='g')
plt.plot(np.arange(0, 250), lmax, c ='b')
plt.title("Labor Plot")
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# ## Problem 8

# %%
ymean1 = y.mean(axis=1).mean()
cmean1 = c.mean(axis=1).mean()
Imean1 = I.mean(axis=1).mean()
lmean1 = l.mean(axis=1).mean()

ymean2 = stats.sem(y.mean(axis=1))
cmean2 = stats.sem(c.mean(axis=1))
Imean2 = stats.sem(I.mean(axis=1))
lmean2 = stats.sem(l.mean(axis=1))

ystd1 = y.std(axis=1).mean()
cstd1 = c.std(axis=1).mean()
Istd1 = I.std(axis=1).mean()
lstd1 = l.std(axis=1).mean()

ystd2 = stats.sem(y.std(axis=1))
cstd2 = stats.sem(c.std(axis=1))
Istd2 = stats.sem(I.std(axis=1))
lstd2 = stats.sem(l.std(axis=1))

ycv1 = (y.mean(axis=1)/y.std(axis=1)).mean()
ccv1 = (c.mean(axis=1)/c.std(axis=1)).mean()
Icv1 = (I.mean(axis=1)/I.std(axis=1)).mean()
lcv1 = (l.mean(axis=1)/l.std(axis=1)).mean()

ycv2 = stats.sem((y.mean(axis=1)/y.std(axis=1)))
ccv2 = stats.sem((c.mean(axis=1)/c.std(axis=1)))
Icv2 = stats.sem((I.mean(axis=1)/I.std(axis=1)))
lcv2 = stats.sem((l.mean(axis=1)/l.std(axis=1)))

crv1 = (c.std(axis=1)/y.std(axis=1)).mean()
Irv1 = (I.std(axis=1)/y.std(axis=1)).mean()
lrv1 = (l.std(axis=1)/y.std(axis=1)).mean()

crv2 = stats.sem((c.std(axis=1)/y.std(axis=1)))
Irv2 = stats.sem((I.std(axis=1)/y.std(axis=1)))
lrv2 = stats.sem((l.std(axis=1)/y.std(axis=1)))

yp = np.zeros(10000-1)
cp = np.zeros(10000-1)
Ip = np.zeros(10000-1)
lp = np.zeros(10000-1)

cc = np.zeros(10000)
Ic = np.zeros(10000)
lc = np.zeros(10000)
    
for i in range(10000):
    cc[i] = np.corrcoef(y[i, :], c[i, :])[0, 1]
    Ic[i] = np.corrcoef(y[i, :], I[i, :])[0, 1]
    lc[i] = np.corrcoef(y[i, :], l[i, :])[0, 1]

cc1 = cc.mean()
Ic1 = Ic.mean()
lc1 = lc.mean()
cc2 = stats.sem(cc)
Ic2 = stats.sem(Ic)
lc2 = stats.sem(lc)

for i in range(10000-1):
    yp[i] = np.corrcoef(y[i, :-1], y[i, 1:])[0, 1] 
    cp[i] = np.corrcoef(y[i, :-1], c[i, 1:])[0, 1] 
    Ip[i] = np.corrcoef(y[i, :-1], I[i, 1:])[0, 1] 
    lp[i] = np.corrcoef(y[i, :-1], l[i, 1:])[0, 1] 

yp1 = yp.mean()
cp1 = cp.mean()
Ip1 = Ip.mean()
lp1 = lp.mean()
yp2 = stats.sem(yp)
cp2 = stats.sem(cp)
Ip2 = stats.sem(Ip)
lp2 = stats.sem(lp)

# %%
print("mean (mean & std), in the order of GDP, Consumption, Investment, Labor")
print(str(ymean1)+"  "+str(ymean2))
print(str(cmean1)+"  "+str(cmean2))
print(str(Imean1)+"  "+str(Imean2))
print(str(lmean1)+"  "+str(lmean2))
print("")
print("volatility")
print(str(ystd1)+"  "+str(ystd2))
print(str(cstd1)+"  "+str(cstd2))
print(str(Istd1)+"  "+str(Istd2))
print(str(lstd1)+"  "+str(lstd2))
print("")
print("Coefficient of Variation")
print(str(ycv1)+"  "+str(ycv2))
print(str(ccv1)+"  "+str(ccv2))
print(str(Icv1)+"  "+str(Icv2))
print(str(lcv1)+"  "+str(lcv2))
print("")
print("Relative volatility")
print(str(crv1)+"  "+str(crv2))
print(str(Irv1)+"  "+str(Irv2))
print(str(lrv1)+"  "+str(lrv2))
print("")
print("Persistence")
print(str(yp1)+"  "+str(yp2))
print(str(cp1)+"  "+str(cp2))
print(str(Ip1)+"  "+str(Ip2))
print(str(lp1)+"  "+str(lp2))
print("")
print("Cyclicality")
print(str(cc1)+"  "+str(cc2))
print(str(Ic1)+"  "+str(Ic2))
print(str(lc1)+"  "+str(lc2))
# Out:
# mean (mean & std), in the order of GDP, Consumption, Investment, Labor
# 1.28521323732  0.000222856598047
# 0.861160072256  8.09861378602e-05
# 0.422986288059  7.87636695194e-05
# 0.579812110929  2.0923443458e-05
#
# volatility
# 0.066983288189  0.000104605592217
# 0.0252832367381  3.34699818193e-05
# 0.0253949755773  3.69548009903e-05
# 0.00472737993911  1.06488739484e-05
#
# Coefficient of Variation
# 19.6473543765  0.0303276874281
# 34.6385696229  0.0444650981749
# 17.0018106699  0.0244135897629
# 129.109109573  0.300940550659
#
# Relative volatility
# 0.37899135882  0.000127806215703
# 0.379763382302  5.65890830681e-05
# 0.0699280468258  6.28739465723e-05
#
# Persistence
# 0.910946334268  0.000273702122261
# 0.835503935005  0.000423121137889
# 0.801347472797  0.000537893993977
# -0.802813127899  0.000448876345233
#
# Cyclicality
# 0.871006454402  0.000271759979312
# 0.894205404074  0.000292808560775
# -0.736260129703  0.000640090250011

# %% [markdown]
# ## Problem 9

# %%
# Generate impulse response function
# The rows of the matrix correspond to z, k, l, y, i, c, in that order
shock = np.zeros((6, 41))

k = np.zeros_like(41)
shock[0, 0]=0
shock[1, 0]=0
shock[2, 0]=0

for i in range(1, 41):
    shock[0, i] = rho ** i * sigmaz
    shock[1, i] = PP[0, 0] * shock[1, i - 1] + QQ[0, 0] * shock[0, i] #log capital
    shock[2, i] = PP[1, 0] * shock[1, i - 1] + QQ[1, 0] * shock[0, i] #log labor
shock[1, :] = k_ss * np.exp(shock[1, :])
shock[2, :] = l_ss * np.exp(shock[2, :])

w = get_w(shock[1, :], shock[2, :], shock[0, :])
r = get_r(shock[1, :], shock[2, :], shock[0, :])

for i in range(40):
    shock[3, i] = shock[1, i] ** alpha * shock[1, i] ** (1 - alpha)
    shock[4, i] = shock[1, i + 1] - (1 - delta) * shock[1, i]
    shock[5, i] = w[i] * shock[2, i] + (r[i] - delta) * shock[1, i] + shock[1, i] - shock[1, i+1]

# %%
# Plot
pylab.rcParams['figure.figsize'] = (10, 5)
plt.subplot(221)
plt.scatter(np.arange(0, 40), shock[3, :][0: 40], s = 5)
plt.title("Output impulse response")
plt.subplot(222)
plt.scatter(np.arange(0, 40), shock[5, :][0: 40], s = 5)
plt.title("Consumption impulse response")
plt.subplot(223)
plt.scatter(np.arange(0, 40), shock[4, :][0: 40], s = 5)
plt.title("Investment impulse response")
plt.subplot(224)
plt.scatter(np.arange(0, 40), shock[2, :][0: 40], s = 5)
plt.title("Labor impulse response")
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# ## Problem 10
# I will use the same calibrated values for the parameters as we did for problem set1, for the OLG model.
# I also assume the same functional forms fors the housholds' utility function and firm's production fucntion:
# $$u(c) = \frac{c^{1-\sigma}-1}{1 - \sigma}$$
# $$Y = AK^{\alpha}L^{1-\alpha}$$
#
# In the notation of DSGE models, the state variables for an OLG model with 3 generations are
#
# $$X_t = (k_{2, t+1}, k_{3, t+1})$$

# %%
# Household Parameters
nvec = np.array([1.0,1.0,0.2]) # labor supply
yrs_live = 60
s = 3
beta = 0.442
sigma = 3

# Firm Parameters
alpha = 0.35
delta_annual = 0.05
delta = 1- ((1 - delta_annual) ** (yrs_live/s))

# %%
# Define functions
def get_L(nvec): # function for aggregate labor
    L = nvec.sum()
    return L

def get_K(kvec): # function for aggregate capital
    K = kvec.sum()
    return K

def get_w(K, L, z): # function for wage
    w = (1 - alpha) * np.exp(z) * ((K / L) ** alpha)
    return w

def get_r(K, L, z): # function for interest rate
    r = alpha * np.exp(z) * ((L / K) ** (1 - alpha)) - delta
    return r

# %%
def Model_olg(theta0, params):
    # unpack theat0
    (k2pp, k3pp, k2p, k3p, k2, k3, zp, z) = theta0
    
    Kpp = get_K(np.array([k2pp, k3pp]))
    Kp = get_K(np.array([k2p, k3p]))
    K = get_K(np.array([k2, k3]))
    L = get_L(nvec)
    
    wp = get_w(Kp, L, zp)
    w = get_w(K, L, z)
    rp = get_r(Kp, L, zp)
    r = get_r(K, L, z)
    
    c1 = w * nvec[0] - k2p
    c2 = (1 + r) * k2 + w * nvec[1] - k3p
    c2p = (1 + rp) * k2p + wp * nvec[1] - k3pp
    c3p = (1 + rp) * k3p + wp * nvec[2]
    
    # Evaluate Euler equations
    E1 = c1 ** (-sigma) - beta * (1 + rp) * c2p ** (-sigma)
    E2 = c2 ** (-sigma) - beta * (1 + rp) * c3p ** (-sigma)
    
    return np.array([E1, E2])

# %%
# make parameter list to pass to functions
params = (nvec, beta, sigma, alpha)

# set LinApp parameters
nx = 2
ny = 0
nz = 1
zbar = np.array([0.])

# %%
# take a guess for steady state values of k and ell
guessk = np.array([.02, .04])

# find the steady state values using LinApp_FindSS
k2bar, k3bar = LinApp_FindSS(Model_olg, params, guessk, zbar, nx, ny)
print ('k2bar: ', k2bar)
print ('k3bar: ', k3bar)

# set up steady state input vector
theta0 = np.array([k2bar, k3bar, k2bar, k3bar, k2bar, k3bar, 0., 0.])

# check SS solution
check = Model_olg(theta0, params)
print ('check: ', check)
if np.max(np.abs(check)) > 1.E-6:
    print ('Have NOT found steady state')
# Out:
# k2bar:  0.0193125457386
# k3bar:  0.0584111733061
# check:  [  1.85025328e-11  -2.07748485e-10]

# %% [markdown]
# This is exactly the same as we got for the steady-state values of savings, using TPI.

# %%
# find the derivatives matrices
[AA, BB, CC, DD, FF, GG, HH, JJ, KK, LL, MM, WW, TT] = \
    LinApp_Deriv(Model_olg, params, theta0, nx, ny, nz, logX = True)
print('FF: ', FF)
print('GG: ', GG)
print('HH: ', HH)
print('LL: ', LL)
print('MM: ', MM)

# set value for NN    
NN = 1
    
# find the policy and jump function coefficients
PP, QQ, UU, RR, SS, VV = \
    LinApp_Solve(AA,BB,CC,DD,FF,GG,HH,JJ,KK,LL,MM,WW,TT,NN,zbar,Sylv=0)
print ('PP:',PP)
print ('QQ', QQ)
# Out:
# FF:  [[   0.         -137.73185791]
#  [   0.            0.        ]]
# GG:  [[ 251.2494762   128.79794953]
#  [ -18.77382012  305.15817507]]
# HH:  [[ -47.53559541 -143.77234049]
#  [-115.38715412  -37.38011659]]
# LL:  [[ 468.12086235]
#  [ 200.17478582]]
# MM:  [[-546.59409199]
#  [-405.73953902]]
# PP: [[ 0.03530495  0.63635142]
#  [ 0.38029446  0.16164359]]
# QQ [[ 0.5051438]
#  [ 0.7047107]]

# %%
k2_start = np.log(0.8 * k2bar) - np.log(k2bar)
k3_start = np.log(1.1 * k3bar) - np.log(k3bar)

kmat = np.zeros((2, 20)) # matrix for k2, k3

kmat[0, 0] = k2_start
kmat[1, 0] = k3_start

for i in range(1, 20):
    kmat[:, i] = np.dot(PP, kmat[:, i-1]) # we don't need Q since Z is fixed
kmat[0, :] = k2bar * np.exp(kmat[0, :]) 
kmat[1, :] = k3bar * np.exp(kmat[1, :]) 

k_agg = kmat[0, :] + kmat[1, :]

# %%
# %matplotlib inline
pylab.rcParams['figure.figsize'] = (10, 5)
plt.subplot(221)
plt.plot(np.arange(0, 20), kmat[0, :])
plt.title('Time Path of K2')
plt.subplot(222)
plt.plot(np.arange(0, 20), kmat[1, :])
plt.title('Time Path of K3')
plt.subplot(223)
plt.plot(np.arange(0, 20), k_agg)
plt.title('Time Path of Aggregate Capital')
plt.tight_layout()
plt.show()

# %% [markdown]
# The plots we obtain are similar to the ones generated using TPI. Log-linearization is much faster than iteration, however we loss some accuracy since we are trying to linearize around the steady-state as opposed to calculate the precise values. However, this loss in accuracy does not hinder our ability to understand the general trends going on in the economy (how capital levels reach steady state). Notably, the time taken for aggregate capital to be close to steady-state level, as predicted by log-linearization, is also very similar to the one predicted by TPI (about 7 periods).

# %% [markdown]
# ## Problem 11
# To calculate P and Q, we can use the same function for problem 10, but only need to change N to $\rho = 0.9^{20}$

# %%
rhoz = 0.9 ** 20
sigmaz = 0.02

# find the derivatives matrices
[AA, BB, CC, DD, FF, GG, HH, JJ, KK, LL, MM, WW, TT] = \
    LinApp_Deriv(Model_olg, params, theta0, nx, ny, nz, logX = True)
print('FF: ', FF)
print('GG: ', GG)
print('HH: ', HH)
print('LL: ', LL)
print('MM: ', MM)

# set value for NN    
NN = rhoz
    
# find the policy and jump function coefficients
PP, QQ, UU, RR, SS, VV = \
    LinApp_Solve(AA,BB,CC,DD,FF,GG,HH,JJ,KK,LL,MM,WW,TT,NN,zbar,Sylv=0)
print ('PP:',PP)
print ('QQ', QQ)
# Out:
# FF:  [[   0.         -137.73185791]
#  [   0.            0.        ]]
# GG:  [[ 251.2494762   128.79794953]
#  [ -18.77382012  305.15817507]]
# HH:  [[ -47.53559541 -143.77234049]
#  [-115.38715412  -37.38011659]]
# LL:  [[ 468.12086235]
#  [ 200.17478582]]
# MM:  [[-546.59409199]
#  [-405.73953902]]
# PP: [[ 0.03530495  0.63635142]
#  [ 0.38029446  0.16164359]]
# QQ [[ 1.84670944]
#  [ 1.36346584]]

# %% [markdown]
# And now we will simulate using P, and Q, same as before.

# %%
e = np.random.normal(0, scale=sigmaz, size=(10000, 251))
z = np.zeros_like(e)
z[:, 0] = np.zeros(10000)
for i in range(1, 251):
    z[:, i] = rhoz * z[:, i - 1] + e[:, i]

k2 = np.zeros_like(e)
k3 = np.zeros_like(e)
k_agg = np.zeros_like(e)
c = np.zeros_like(e)
y = np.zeros_like(e)
I = np.zeros_like(e)

for i in range(1, 251):
    k2[:, i] = PP[0, 0] * k2[:, i-1] + PP[0, 1] * k3[:, i-1] + QQ[0] * z[:, i]
    k3[:, i] = PP[1, 0] * k2[:, i-1] + PP[1, 1] * k3[:, i-1] + QQ[0] * z[:, i]
k2 = k2bar * np.exp(k2)
k3 = k3bar * np.exp(k3)
k_agg = k2 + k3

w = get_w(k_agg, 2.2, z)
r = get_r(k_agg, 2.2, z)

for i in range(250):
    y[:, i] = k_agg[:, i] ** alpha * 2.2 ** (1 - alpha) * np.exp(z[:, i])
    I[:, i] = k_agg[:, i + 1] - (1 - delta) * k_agg[:, i]
    c[:, i] = w[:, i] - k2[:, i + 1] + w[:, i] + (1 + r[:, i]) * k2[:, i] - k3[:, i+1] + w[:, i] * 0.2 + (1 + r[:,i]) * k3[:, i]

y = y[:, 0:250]
I = I[:, 0:250]
c = c[:, 0:250]

ymean = y.mean(axis=0)
cmean = c.mean(axis=0)
Imean = I.mean(axis=0)

# %%
ymin = np.zeros(250)
ymax = np.zeros(250)
cmin = np.zeros(250)
cmax = np.zeros(250)
Imin = np.zeros(250)
Imax = np.zeros(250)

for i in range(250):
    ymin[i] = np.percentile(y[:, i], 5)
    ymax[i] = np.percentile(y[:, i], 95)
    cmin[i] = np.percentile(c[:, i], 5)
    cmax[i] = np.percentile(c[:, i], 95)
    Imin[i] = np.percentile(I[:, i], 5)
    Imax[i] = np.percentile(I[:, i], 95)
    

pylab.rcParams['figure.figsize'] = (10, 5)
plt.subplot(221)
plt.plot(np.arange(0, 250), ymean[0: 250], c='r')
plt.plot(np.arange(0, 250), ymin, c ='g')
plt.plot(np.arange(0, 250), ymax, c ='b')
plt.title("Output Plot")
plt.subplot(222)
plt.plot(np.arange(0, 250), cmean[0: 250], c='r')
plt.plot(np.arange(0, 250), cmin, c ='g')
plt.plot(np.arange(0, 250), cmax, c ='b')
plt.title("Consumption Plot")
plt.subplot(223)
plt.plot(np.arange(0, 250), Imean[0: 250], c='r')
plt.plot(np.arange(0, 250), Imin, c ='g')
plt.plot(np.arange(0, 250), Imax, c ='b')
plt.title("Investmenr Plot")
plt.tight_layout()
plt.show()
print("average output: " + str(ymean.mean()))
print("average investment: " + str(Imean.mean()))
print("average consumption: " + str(cmean.mean()))
# Out:
# average output: 0.682939491877
# average investment: 0.049864172828
# average consumption: 0.633075319049
